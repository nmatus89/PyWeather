# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from pprint import pprint

# Import API key
from config import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "PyWeather/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 587

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Creat url for API call
url = "https://api.openweathermap.org/data/2.5/weather?"

#Create lists to append API data
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lon = []
temp_max = []
speed = []

#Loop to get the city data
for city in cities:
    query_url = url + "q=" + city + "&appid=" + api_key 
    response = requests.get(query_url).json()
    #if response['cod'] == 200:
    try:
        city_name.append(response['name'])
        cloudiness.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humidity.append(response['main']['humidity'])
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        temp_max.append(response['main']['temp_max'])
        speed.append(response['wind']['speed'])
        print(f"Processing record {city}")
    #else:
    except:
        print("City not found. Skipping...")
# Out:
# Processing record kapaa
# Processing record dzaoudzi
# Processing record punta arenas
# Processing record busselton
# Processing record yellowknife
# Processing record bathsheba
# Processing record joshimath
# Processing record touros
# Processing record erenhot
# Processing record ushuaia
# Processing record luderitz
# Processing record bluff
# Processing record avarua
# Processing record zapadnaya dvina
# Processing record barrow
# Processing record paka
# Processing record bredasdorp
# Processing record villa rica
# Processing record bubaque
# Processing record gua musang
# Processing record butaritari
# Processing record torbay
# Processing record ribeira grande
# Processing record castelnaudary
# Processing record mataura
# Processing record itarema
# Processing record puerto ayora
# Processing record rikitea
# Processing record flinders
# City not found. Skipping...
# Processing record victor harbor
# Processing record unai
# Processing record sisimiut
# Processing record tasiilaq
# Processing record alofi
# Processing record hermanus
# Processing record broome
# Processing record kavaratti
# Processing record albany
# Processing record jamestown
# Processing record saint marys
# Processing record sassandra
# Processing record kodiak
# Processing record airai
# Processing record hamza
# Processing record salinas
# Processing record valladolid
# City not found. Skipping...
# Processing record pacific grove
# Processing record qeshm
# Processing record cape town
# Processing record sioux lookout
# Processing record borovichi
# Processing record nanortalik
# City not found. Skipping...
# Processing record merauke
# Processing record provideniya
# Processing record hilo
# Processing record rio gallegos
# City not found. Skipping...
# Processing record kajaani
# Processing record whitehorse
# City not found. Skipping...
# Processing record port hedland
# Processing record port alfred
# Processing record podgorica
# Processing record ilulissat
# Processing record necochea
# Processing record lebu
# Processing record estelle
# Processing record fomboni
# Processing record nueve de julio
# Processing record dingle
# Processing record cortez
# Processing record zeya
# Processing record dikson
# Processing record rio grande
# Processing record atuona
# Processing record vostok
# Processing record clyde river
# Processing record nuuk
# Processing record hofn
# Processing record aklavik
# Processing record tiksi
# Processing record sao filipe
# Processing record goulburn
# Processing record tura
# Processing record mayumba
# Processing record tiarei
# City not found. Skipping...
# Processing record longyearbyen
# Processing record menongue
# Processing record teruel
# Processing record new norfolk
# City not found. Skipping...
# Processing record huarmey
# Processing record pagudpud
# Processing record kruisfontein
# Processing record tuktoyaktuk
# Processing record hithadhoo
# Processing record mahebourg
# Processing record obihiro
# Processing record saint-philippe
# City not found. Skipping...
# City not found. Skipping...
# Processing record ilo
# Processing record marienburg
# Processing record thompson
# Processing record sitka
# Processing record east london
# Processing record mar del plata
# Processing record talnakh
# Processing record dubbo
# City not found. Skipping...
# Processing record severo-kurilsk
# Processing record mali

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dic = {
    'City': city_name,
    'Cloudiness': cloudiness,
    'Country': country,
    'Date': date,
    'Humidity': humidity,
    'Lat': lat,
    'Lng': lon,
    'Max Temp': temp_max,
    'Wind Speed': speed
}

weather_df = pd.DataFrame(weather_dic)

# %%
weather_df.count()
# Out:
# City          542
# Cloudiness    542
# Country       542
# Date          542
# Humidity      542
# Lat           542
# Lng           542
# Max Temp      542
# Wind Speed    542
# dtype: int64

# %%
weather_df.head()
# Out:
#             City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0    New Norfolk          75      AU  1563385136        61 -42.78  147.06
# 1         Bosaso           0      SO  1563385137        60  11.28   49.18
# 2  San Cristobal          88      HN  1563385137        48  14.68  -86.92
# 3        Mataura          92      NZ  1563385138        88 -46.19  168.86
# 4   Longyearbyen          75      NO  1563385138        70  78.22   15.63
#
#    Max Temp  Wind Speed
# 0   286.480        5.70
# 1   305.164        3.55
# 2   301.564        4.15
# 3   277.264        3.58
# 4   280.150        2.60

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#Generate scatter plot
plt.scatter(weather_df['Lat'], weather_df['Max Temp'], marker="o", facecolors="blue", edgecolors="blue", alpha = 0.80)
# Incorporate the other graph properties
plt.title("City Latitute vs Max Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature")

# Save Figure
#plt.savefig("PyWheather/lat_vs_temp.png")

plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
#Generate scatter plot
plt.scatter(weather_df['Lat'], weather_df['Humidity'], marker="o", facecolors="blue", edgecolors="blue", alpha = 0.80)
# Incorporate the other graph properties
plt.title("City Latitute vs Humidity")
plt.xlabel("Latitute")
plt.ylabel("Humidity")

# Save Figure
#plt.savefig("PyWheather/lat_vs_temp.png")

plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
#Generate scatter plot
plt.scatter(weather_df['Lat'], weather_df['Cloudiness'], marker="o", facecolors="blue", edgecolors="blue", alpha = 0.80)
# Incorporate the other graph properties
plt.title("City Latitute vs Cloudiness")
plt.xlabel("Latitute")
plt.ylabel("Cloudiness")

# Save Figure
#plt.savefig("PyWheather/lat_vs_temp.png")

plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
#Generate scatter plot
plt.scatter(weather_df['Lat'], weather_df['Wind Speed'], marker="o", facecolors="blue", edgecolors="blue", alpha = 0.80)
# Incorporate the other graph properties
plt.title("City Latitute vs Wind Speed")
plt.xlabel("Latitute")
plt.ylabel("Wind Speed")

# Save Figure
#plt.savefig("PyWheather/lat_vs_temp.png")

plt.show()
